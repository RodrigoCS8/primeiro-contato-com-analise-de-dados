# %% [markdown]
# <a href="https://colab.research.google.com/github/RodrigoCS8/primeiro-contato-com-analise-de-dados/blob/main/Imers%C3%A3o_de_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Imerção de dados**
#
# Dataset contendo informações sobre as reações e respostas das células humanas, de diversas linhagens, aos diferentes tipos de medicamentos/compostos e seus respectivos mecanismos de ação (MoA); disponibilizado pelo Laboratory for Innovation Science at Harvard no Kaggle.
#
# Notebook elaborado com base na 3ª edição da Imersão de Dados da Alura.
#
# Análises feitas por Rodrigo Carvalho.

# %% [markdown]
# **Importanto base de dados:**

# %%
import pandas as pd
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'

dados = pd.read_csv(url_dados, compression = 'zip')
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %% [markdown]
# **Primeiros 5 resultados:**

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %% [markdown]
# **Ultimos 5 resultados:**

# %%
dados.tail()
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %% [markdown]
# **Total de linhas e colunas:**

# %%
dados.shape
# Out:
# (23814, 877)

# %% [markdown]
# **Evidenciando tipos de tratamento:**

# %%
dados['tratamento']
# Out:
# 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object

# %%
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %% [markdown]
# **Tempos de ação analisados:**

# %%
dados['tempo'].unique()
# Out:
# array([24, 72, 48])

# %% [markdown]
# **Tipos de doses:**

# %%
dados['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %% [markdown]
# **Drogas presentes no experiemnto:**

# %%
dados['droga'].unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %% [markdown]
# **Proporção entre as classes tratamento:**

# %%
dados['tratamento'].value_counts(normalize = True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %% [markdown]
# **Quantidade de tipos de drogas analisadas:**

# %%
dados['droga'].value_counts()
# Out:
# cacb2b860    1866
# 87d714366     718
# 9f80f3f77     246
# 8b87a7a83     203
# 5628cb3ee     202
#              ...
# 263b9a195       1
# 209a68d23       1
# f5c443039       1
# b3f24a171       1
# 4a8eda087       1
# Name: droga, Length: 3289, dtype: int64

# %% [markdown]
# **Porporção entras as doses:**

# %%
dados['dose'].value_counts(normalize = True)
# Out:
# D1    0.510078
# D2    0.489922
# Name: dose, dtype: float64

# %%
dados['tratamento'].value_counts().plot.pie(autopct='%1.1f%%')
plt.title("Tratamento")
# Out:
# Text(0.5, 1.0, 'Tratamento')

# %%
dados['tempo'].value_counts().plot.pie(colors = ('blue', 'green', 'orange') , autopct='%1.1f%%')
plt.title("Tempo de ação")
# Out:
# Text(0.5, 1.0, 'Tempo de ação')

# %%
dados['tempo'].value_counts().plot.bar()
plt.title("Tempo de ação")
# Out:
# Text(0.5, 1.0, 'Tempo de ação')

# %% [markdown]
# **Consulta de dados com a calsse de dose "D1":**

# %%
dados.query('dose == "D1"')
# Out:
#                  id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 5      id_001762a82  com_droga     24   D1  ...  1.2120  0.3765  0.7848  1.3990
# ...             ...        ...    ...  ...  ...     ...     ...     ...     ...
# 23804  id_fff506720  com_droga     24   D1  ... -0.4097  0.2282 -0.3213 -0.0836
# 23807  id_fff7e6992  com_droga     48   D1  ...  0.3738  0.8636  0.4494  0.1218
# 23808  id_fff8c2444  com_droga     72   D1  ... -0.7415  0.8413 -0.4259  0.2434
# 23812  id_fffcb9e7c  com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b  com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# ...

# %% [markdown]
# * preocupado com possiveis problemas com o python removi " - " da tabela

# %%
dados.columns = dados.columns.str.replace('-', '')
dados
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %% [markdown]
# **Resumo do 1º dia de analises:**
#
# O experimento esta analisando o efeito de determinadas compostos em genes e celulas.

# %% [markdown]
# * Mudança do nome "Droga" a "Composto" para melhor entendimento.

# %%
mapa = {'droga': 'composto'}
dados.rename(columns=mapa, inplace=True)

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...     c96     c97     c98     c99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %% [markdown]
# **Coletando os 5 compostos mais ultilizados:**

# %%
cod_compostos = dados['composto'].value_counts().index[0:5]

# %%
cod_compostos
# Out:
# Index(['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee'], dtype='object')

# %%
dados.query('composto in @cod_compostos')
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# 16     id_002fb9c19     com_droga     48   D1  ... -9.9840 -9.9840 -9.9840 -6.7840
# 25     id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 38     id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 40     id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.9180
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23793  id_ffd26f361  com_controle     48   D2  ...  0.8813  0.7757 -0.5272  0.7082
# 23802  id_fff3976bd     com_droga     24   D1  ... -8.4480 -4.4550 -5.7930 -3.7000
# 23805  id_fff6df1c5     com_droga     48   D2  ...  0.1516  0.4503 -0.6312 -0.8302
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()
plt.figure (figsize=(8,6))
ax = sns.countplot(x = 'composto', data = dados.query('composto in @cod_compostos'), order = cod_compostos)
plt.ylabel("Quantas x foi usado", fontsize=17)
plt.xlabel("Compostos usados", fontsize=17)
ax.set_title ('Top 5 compostos', fontsize = 20)
plt.show()

# %% [markdown]
# **Analisando dados de expressão gênica:**

# %%
len(dados['g0'].unique())
# Out:
# 14367

# %%
dados['g0'].min()
# Out:
# -5.513

# %%
dados['g0'].max()
# Out:
# 10.0

# %%
dados['g0'].hist(bins = 100)

# %%
dados['g19'].hist(bins = 100)

# %%
dados.describe()
# Out:
#               tempo            g0  ...           c98           c99
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean      48.020156      0.248366  ...     -0.470252     -0.301505
# std       19.402807      1.393399  ...      1.834828      1.407918
# min       24.000000     -5.513000  ...    -10.000000    -10.000000
# 25%       24.000000     -0.473075  ...     -0.592600     -0.562900
# 50%       48.000000     -0.008850  ...      0.014000     -0.019500
# 75%       72.000000      0.525700  ...      0.461275      0.438650
# max       72.000000     10.000000  ...      3.111000      3.805000
#
# [8 rows x 873 columns]

# %% [markdown]
# Legenda:
#
# count = quantidade de elementos/número de registros;
#
# mean = média aritmérica;
#
# std = desvio padrão;
#
# min = valor mínimo dos dados;
#
# max = valor máximo dos dados;
#
# 25% = primeiro quartil, retorna os primeiros 25% dos dados;
#
# 50% = segundo quartil, retorna os primeiros 50% dos dados;
#
# 75% = terceiro quartil, retorna os primeiros 75% dos dados.

# %%
dados[['g0', 'g1']]
# Out:
#            g0      g1
# 0      1.0620  0.5577
# 1      0.0743  0.4087
# 2      0.6280  0.5817
# 3     -0.5138 -0.2491
# 4     -0.3254 -0.4009
# ...       ...     ...
# 23809  0.1394 -0.0636
# 23810 -1.3260  0.3478
# 23811  0.3942  0.3756
# 23812  0.6660  0.2324
# 23813 -0.8598  1.0240
#
# [23814 rows x 2 columns]

# %%
dados.loc[:,'g0':'g771'].describe()
# Out:
#                  g0            g1  ...          g770          g771
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean       0.248366     -0.095684  ...     -0.219210      0.101524
# std        1.393399      0.812363  ...      1.326193      1.417674
# min       -5.513000     -5.737000  ...    -10.000000    -10.000000
# 25%       -0.473075     -0.562200  ...     -0.554400     -0.523800
# 50%       -0.008850     -0.046600  ...      0.028700     -0.006500
# 75%        0.525700      0.403075  ...      0.496400      0.536950
# max       10.000000      5.039000  ...     10.000000     10.000000
#
# [8 rows x 772 columns]

# %%
plt.figure(figsize=(8, 4))
ax = dados.loc[:, 'g-0':'g-771'].describe().T['mean'].hist(bins = 50)
ax.set_title('Histograma das médias de expressão gênica:')
plt.show()

# %% [markdown]
# **Alterando o parâmetro estatístico a ser analisado (mínimo e máximo) para observar as difenreças de cada métrica:**

# %%
dados.loc[:,'g0':'g771'].describe().T['min'].hist(bins=30)

# %%
dados.loc[:,'g0':'g771'].describe().T['max'].hist(bins=30)

# %%
dados.loc[:,'c0':'c99'].describe().T['mean'].hist(bins=50)

# %%
sns.boxplot(x='g0' , data=dados)

# %%
plt.figure(figsize=(10,8))
sns.boxplot(y='g0', x='tratamento' , data=dados)

# %%
import seaborn as sns
plt.figure (figsize=(8,6))
sns.histplot(dados.g3, bins=50, kde=True)
plt.title("Dados de G3", fontsize = 17)
plt.ylabel("N° de experimentos feitos", fontsize=17)
plt.xlabel("Expressões gênicas", fontsize=17)
# Out:
# Text(0.5, 0, 'Expressões gênicas')

# %%
sns.histplot(data=dados.loc[:, 'g0':'g73'].describe().T['mean'], color = 'mediumorchid', kde=True)
plt.title("Média de g0 até g73", fontsize = 17)
plt.ylabel("N° de experimentos feitos", fontsize=17)
plt.xlabel("Expressões gênicas", fontsize=17)
# Out:
# Text(0.5, 0, 'Expressões gênicas')

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='g8', data=dados, color = 'mediumorchid')

# %%
plt.figure (figsize=(8,6))
sns.histplot(dados.g8, bins=50, kde=True, color = 'mediumorchid')
plt.title("Dados de G8", fontsize = 17)
plt.ylabel("N° de experimentos feitos", fontsize=17)
plt.xlabel("Expressões gênicas", fontsize=17)
# Out:
# Text(0.5, 0, 'Expressões gênicas')

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='g8', y='tratamento', data=dados, color = 'mediumorchid')

# %% [markdown]
# **Resumo do 2º dia de analises:**

# %% [markdown]
# Com os graficos podemos ver a quantidade de experimentos feitos em comparação com o uso de compostos e o não uso.

# %% [markdown]
# Dia 3

# %%
pd.crosstab(dados['dose'], dados['tempo'])
# Out:
# tempo    24    48    72
# dose
# D1     3886  4354  3907
# D2     3886  3896  3885

# %%
pd.crosstab([dados['dose'], dados['tempo']],  dados['tratamento'])
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %%
pd.crosstab([dados['dose'], dados['tempo']],  dados['tratamento'], values=dados['g0'], aggfunc='mean')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -0.251760   0.367996
#      48        -0.122773   0.412469
#      72        -0.295271   0.286250
# D2   24         0.010754   0.115253
#      48         0.013174   0.214480
#      72         0.070250   0.253439

# %%
dados[['g0', 'g3']]
# Out:
#            g0      g3
# 0      1.0620 -0.6208
# 1      0.0743  0.0604
# 2      0.6280 -0.0764
# 3     -0.5138  0.5288
# 4     -0.3254  0.6919
# ...       ...     ...
# 23809  0.1394 -0.5080
# 23810 -1.3260  0.9905
# 23811  0.3942 -0.7389
# 23812  0.6660  0.2044
# 23813 -0.8598  0.7952
#
# [23814 rows x 2 columns]

# %%
sns.scatterplot(x='g0', y = 'g3', data=dados)

# %%
sns.scatterplot(x='g0', y = 'g8', data=dados)

# %%
sns.lmplot(data=dados, x='g0', y='g8', line_kws={'color': 'red'})

# %%
sns.lmplot(data=dados, x='g0', y='g8', line_kws={'color': 'red'}, col='tratamento', row='tempo')

# %%
dados.loc[:,'g0':'g771'].corr()
# Out:
#             g0        g1        g2  ...      g769      g770      g771
# g0    1.000000  0.086032  0.176188  ... -0.127375 -0.514201  0.405908
# g1    0.086032  1.000000 -0.054518  ... -0.006866 -0.095108 -0.032233
# g2    0.176188 -0.054518  1.000000  ...  0.014489 -0.078661  0.103985
# g3    0.011266 -0.027855  0.042633  ... -0.206077 -0.002142  0.058219
# g4    0.403153  0.193647  0.013968  ... -0.172727 -0.363673  0.250713
# ...        ...       ...       ...  ...       ...       ...       ...
# g767 -0.052622 -0.003378 -0.053149  ...  0.065450  0.008603 -0.001136
# g768  0.300241 -0.030756  0.115415  ...  0.079364 -0.382607  0.351651
# g769 -0.127375 -0.006866  0.014489  ...  1.000000  0.135853 -0.083713
# g770 -0.514201 -0.095108 -0.078661  ...  0.135853  1.000000 -0.425063
# g771  0.405908 -0.032233  0.103985  ... -0.083713 -0.425063  1.000000
#
# [772 rows x 772 columns]

# %%
corr = dados.loc[:,'g0':'g50'].corr()

# %%
import numpy as np


# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
corr_celular = dados.loc[:,'c0':'c50'].corr()

# %%
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr_celular, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_celular, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# Desafio 01: Criar tabelas de frequência com pandas.groupby()

# %%
dados.groupby(by=['dose', 'tempo'])['tratamento'].value_counts()
# Out:
# dose  tempo  tratamento
# D1    24     com_droga       3585
#              com_controle     301
#       48     com_droga       4011
#              com_controle     343
#       72     com_droga       3600
#              com_controle     307
# D2    24     com_droga       3581
#              com_controle     305
#       48     com_droga       3591
#              com_controle     305
#       72     com_droga       3580
#              com_controle     305
# Name: tratamento, dtype: int64

# %%
dados.groupby(by=['tempo'])['tratamento'].value_counts()
# Out:
# tempo  tratamento
# 24     com_droga       7166
#        com_controle     606
# 48     com_droga       7602
#        com_controle     648
# 72     com_droga       7180
#        com_controle     612
# Name: tratamento, dtype: int64

# %% [markdown]
# Desafio 02: Normalizar o crosstab pela coluna.

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados ['tratamento'], normalize = 'columns')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.161308   0.163341
#      48         0.183816   0.182750
#      72         0.164523   0.164024
# D2   24         0.163451   0.163158
#      48         0.163451   0.163614
#      72         0.163451   0.163113

# %% [markdown]
# Desafio 03: Explorar outros agregadores.

# %%
pd.pivot_table(dados, index='tratamento', aggfunc='mean')
# Out:
#                     c0        c1       c10  ...       g98       g99      tempo
# tratamento                                  ...
# com_controle  0.127822  0.194264  0.241917  ...  0.174032  0.037182  48.077170
# com_droga    -0.396219 -0.510589 -0.547917  ... -0.296023 -0.032029  48.015309
#
# [2 rows x 873 columns]

# %%
dados.agg({'tempo' : ['max', 'min'], 'dose' : ['min', 'max']})
# Out:
#      tempo dose
# max     72   D2
# min     24   D1

# %% [markdown]
# Desafio 04: Explorar o melt.

# %%
pd.melt(dados, id_vars= ['tempo', 'dose'])
# Out:
#           tempo dose variable         value
# 0            24   D1       id  id_000644bb2
# 1            72   D1       id  id_000779bfc
# 2            48   D1       id  id_000a6266a
# 3            48   D1       id  id_0015fd391
# 4            72   D2       id  id_001626bd3
# ...         ...  ...      ...           ...
# 20837245     24   D2      c99         0.468
# 20837246     24   D2      c99        0.3689
# 20837247     48   D2      c99        0.3808
# 20837248     24   D1      c99         0.074
# 20837249     72   D1      c99        -4.252
#
# [20837250 rows x 4 columns]

# %%
pd.melt(dados, id_vars= ['tratamento', 'dose'])
# Out:
#             tratamento dose variable         value
# 0            com_droga   D1       id  id_000644bb2
# 1            com_droga   D1       id  id_000779bfc
# 2            com_droga   D1       id  id_000a6266a
# 3            com_droga   D1       id  id_0015fd391
# 4            com_droga   D2       id  id_001626bd3
# ...                ...  ...      ...           ...
# 20837245     com_droga   D2      c99         0.468
# 20837246     com_droga   D2      c99        0.3689
# 20837247  com_controle   D2      c99        0.3808
# 20837248     com_droga   D1      c99         0.074
# 20837249     com_droga   D1      c99        -4.252
#
# [20837250 rows x 4 columns]

# %% [markdown]
# Desafio 05: Calcular e analisar a correlação entre G e C. Refletir sobre os efeitos biológicos.

# %%
g = pd.DataFrame(dados[dados['dose'] == 'D1'].loc[:,'g0':'g20'])
c = pd.DataFrame(dados[dados['dose'] == 'D1'].loc[:,'c0':'c20'])
gec = pd.concat([g, c], axis =1, join = 'inner')
gec = gec.corr()
gec_corr = gec.loc['c0':'c20','g0':'g20']
gec_corr
# Out:
#            g0        g1        g2  ...       g18       g19       g20
# c0  -0.623017  0.088438 -0.120350  ...  0.112343  0.215256  0.451062
# c1  -0.634405  0.080976 -0.132486  ...  0.074919  0.170210  0.388725
# c2  -0.647538  0.075728 -0.127077  ...  0.091147  0.184714  0.435836
# c3  -0.610505  0.126183 -0.118838  ...  0.119921  0.197533  0.416075
# c4  -0.609930  0.080492 -0.128943  ...  0.079127  0.158789  0.430631
# c5  -0.636441  0.114101 -0.119217  ...  0.078648  0.178459  0.439632
# c6  -0.687514  0.083976 -0.132027  ...  0.043948  0.162010  0.442318
# c7  -0.611495  0.103107 -0.137253  ...  0.092528  0.184860  0.458418
# c8  -0.652149  0.104522 -0.128815  ...  0.086552  0.179989  0.425481
# c9  -0.650664  0.117683 -0.115849  ...  0.050152  0.131499  0.434085
# c10 -0.635275  0.103414 -0.129204  ...  0.044731  0.174879  0.476240
# c11 -0.639309  0.087603 -0.128480  ...  0.106703  0.183799  0.458950
# c12 -0.641633  0.092571 -0.134100  ...  0.090550  0.166102  0.460020
# ...

# %% [markdown]
# Desafio 06: Estudar o código que plota a matriz de correlação (heatmap)

# %%
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(gec_corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(gec_corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# Desafio 07: Resumo do que você aprendeu com os dados

# %% [markdown]
# Resumo do que aprendeu:
#
# heatmap;
# correlacionar colunas diferentes dos dados;
# usar o normalize nas colunas;

# %% [markdown]
# Dia 04

# %%
dados_resultados = pd.read_csv('https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_resultados.csv?raw=true')
dados_resultados.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
dados_resultados['acetylcholine_receptor_agonist'].unique()
# Out:
# array([0, 1])

# %%
dados_resultados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23814 entries, 0 to 23813
# Columns: 207 entries, id to wnt_inhibitor
# dtypes: int64(206), object(1)
# memory usage: 37.6+ MB

# %%
contagem_moa = dados_resultados.drop('id', axis=1).sum().sort_values(ascending=False)
contagem_moa
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %%
dados_resultados.drop('id', axis=1).sum(axis=1)
# Out:
# 0        1
# 1        0
# 2        3
# 3        0
# 4        1
#         ..
# 23809    1
# 23810    1
# 23811    0
# 23812    1
# 23813    0
# Length: 23814, dtype: int64

# %%
dados_resultados.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...     c96     c97     c98     c99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
dados_resultados['n_moa'] = dados_resultados.drop('id', axis=1).sum(axis=1)

# %%
dados_resultados['n_moa'] != 0
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 23809     True
# 23810     True
# 23811    False
# 23812     True
# 23813    False
# Name: n_moa, Length: 23814, dtype: bool

# %%
dados_resultados['ativo_moa'] = (dados_resultados['n_moa'] != 0)
dados_resultados.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...      1       True
# 1  id_000779bfc                            0  ...      0      False
# 2  id_000a6266a                            0  ...      3       True
# 3  id_0015fd391                            0  ...      0      False
# 4  id_001626bd3                            0  ...      1       True
#
# [5 rows x 209 columns]

# %%
dados_combinados = pd.merge(dados, dados_resultados[['id','n_moa', 'ativo_moa']], on='id')
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ...     c98     c99  n_moa  ativo_moa
# 0  id_000644bb2  com_droga     24   D1  ...  0.3801  0.4176      1       True
# 1  id_000779bfc  com_droga     72   D1  ...  0.6077  0.7371      0      False
# 2  id_000a6266a  com_droga     48   D1  ... -1.4080  0.6931      3       True
# 3  id_0015fd391  com_droga     48   D1  ... -0.3876 -0.8154      0      False
# 4  id_001626bd3  com_droga     72   D2  ... -0.3786  0.7125      1       True
#
# [5 rows x 879 columns]

# %%
dados_combinados.query('tratamento == "com_controle"' )['ativo_moa'].value_counts()
# Out:
# False    1866
# Name: ativo_moa, dtype: int64

# %%
dados_combinados.query('tratamento == "com_droga"' )['ativo_moa'].value_counts()
# Out:
# True     14447
# False     7501
# Name: ativo_moa, dtype: int64

# %%
composto_principal = dados_combinados['composto'].value_counts().index[:5]
plt.figure(figsize=(12,8))
sns.boxplot(data = dados_combinados.query('composto in @composto_principal'), y= 'g0', x='composto', hue='ativo_moa')
